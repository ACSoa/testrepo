# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Andrey Soares__
#     PhD Student on fisheries sciences

# %% [markdown]
# _I am interested in data science because I use work with data provided from fishing industry and with this data we can develop, for example, models to measure the condition of a determined fishing stock and how it is going to perform on the following years, if it is vulnerable to overfishing or not, etc.. Then we are able to advice stakeholders and government agencies by answer questions about what can be done with this specific fishery activity (e.g. should we decrease fishing pressure or can we increase it?) in a way that it keeps in a sustainable way_

# %% [markdown]
# ### The following code assigns values to x and y variables and applies them into a simple equation

# %%
x = 3
y = x+1
print(x+y)
# Out:
# [1] 7

# %% [markdown]
# |Name|Age|Gender|Smoke?|
# |----|---|------|------|
# |John|30|M|Y|
# |Paul|21|M|N|
# |Maria|35|F|Y|
# |Rachel|25|F|N|
#
# [University I Study](www.ufrpe.br/en)
#
# ![](https://dpnr.vi.gov/wp-content/uploads/2019/04/Why-is-Data-Important.jpg)
